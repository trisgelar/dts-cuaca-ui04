# %% [markdown]
# # Pemodelan Data dengan Deep Learning

# %% [markdown]
# ## Persiapan Dataset

# %%
# Terdapat 3 Dataset yang akan digunakan pada Tugas Akhir
# 2. Keadaan Udara Kota Bandung 2013-2019 (Bulan)
# 3. Kecepatan Angin Kota Bandung 2013-2019 (Bulan)
# 4. Rata-rata suhu Kota Bandung 2015-2019 (Bulan)

# %% [markdown]
# ### Upload Dataset

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-18591c33-de53-49be-88fb-92e4a42a7a7c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-18591c33-de53-49be-88fb-92e4a42a7a7c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving keadaan-udara-menurut-bulan-di-kota-bandung-2013.csv to keadaan-udara-menurut-bulan-di-kota-bandung-2013.csv
# Saving keadaan-udara-menurut-bulan-di-kota-bandung-2014.csv to keadaan-udara-menurut-bulan-di-kota-bandung-2014.csv
# Saving keadaan-udara-menurut-bulan-di-kota-bandung-2015.csv to keadaan-udara-menurut-bulan-di-kota-bandung-2015.csv
# Saving keadaan-udara-menurut-bulan-di-kota-bandung-2016.csv to keadaan-udara-menurut-bulan-di-kota-bandung-2016.csv
# ...

# %% [markdown]
# ### Kombinasi Data Kecepatan Udara, Kecepatan Angin dan Rata-Rata Suhu dengan Pandas

# %%
file_ku = ['keadaan-udara-menurut-bulan-di-kota-bandung-2015.csv',
           'keadaan-udara-menurut-bulan-di-kota-bandung-2016.csv',
           'keadaan-udara-menurut-bulan-di-kota-bandung-2017.csv',
           'keadaan-udara-menurut-bulan-di-kota-bandung-2018.csv',
           'keadaan-udara-menurut-bulan-di-kota-bandung-2019.csv']

file_ka = ['kecepatan--angin--menurut--bulan--di--kota-bandung-2015.csv',
           'kecepatan--angin--menurut--bulan--di--kota-bandung-2016.csv',
           'kecepatan--angin--menurut--bulan--di--kota-bandung-2017.csv',
           'kecepatan--angin--menurut--bulan--di--kota-bandung-2018.csv',
           'kecepatan--angin--menurut--bulan--di--kota-bandung-2019.csv']

file_su = ['rata-rata-suhu-dan-kelembaban-udara-menurut-bulan-di-kota-bandung-2015.csv',
           'rata-rata-suhu-dan-kelembaban-udara-menurut-bulan-di-kota-bandung-2016.csv',
           'rata-rata-suhu-dan-kelembaban-udara-menurut-bulan-di-kota-bandung-2017.csv',
           'rata-rata-suhu-dan-kelembaban-udara-menurut-bulan-di-kota-bandung-2018.csv',
           'rata-rata-suhu-dan-kelembaban-udara-menurut-bulan-di-kota-bandung-2019.csv']

# %%
import pandas as pd
df_keadaan_udara = pd.concat(
    map(pd.read_csv, file_ku), ignore_index=True)
print(df_keadaan_udara)
# Out:
#     Tahun  Bulan  Penguapan (mm)  Tekanan udara (mb)  Kelembapan Nisbi (%)
# 0    2015      1             3.8               924.0                  79.0
# 1    2015      2             3.7               923.8                  80.0
# 2    2015      3             4.0               924.1                  79.0
# 3    2015      4             3.4               923.2                  81.0
# 4    2015      5             3.1               924.1                  77.0
# 5    2015      6             3.4               923.9                  74.0
# 6    2015      7             3.6               924.5                  70.0
# 7    2015      8             4.3               924.4                  66.0
# 8    2015      9             4.8               924.8                  64.0
# 9    2015     10             4.8               925.1                  63.0
# 10   2015     11             3.9               923.4                  79.0
# ...

# %%
import pandas as pd
df_kecepatan_angin = pd.concat(
    map(pd.read_csv, file_ka), ignore_index=True)
print(df_kecepatan_angin)
# Out:
#     Tahun  ...  Kecepatan Angin Terbesar (knot)
# 0    2015  ...                             13.0
# 1    2015  ...                             12.0
# 2    2015  ...                             13.0
# 3    2015  ...                             12.0
# 4    2015  ...                              9.0
# 5    2015  ...                              9.0
# 6    2015  ...                             15.0
# 7    2015  ...                              9.0
# 8    2015  ...                             15.0
# 9    2015  ...                             12.0
# 10   2015  ...                             12.0
# 11   2015  ...                             17.0
# 12   2016  ...                             14.0
# 13   2016  ...                             13.0
# 14   2016  ...                             10.0
# 15   2016  ...                             12.0
# 16   2016  ...                             10.0
# 17   2016  ...                             10.0
# 18   2016  ...                             10.0
# ...

# %%
import pandas as pd
df_suhu = pd.concat(
    map(pd.read_csv, file_su), ignore_index=True)
print(df_suhu)
# Out:
#     Tahun  Bulan  Temperatur Rata-rata  ...  Curah Hujan  Hari Hujan  LPM
# 0    2015      1                  23.2  ...        188.0       22.00   54
# 1    2015      2                  23.1  ...        189.1       20.00   55
# 2    2015      3                  23.4  ...        318.6       28.00   60
# 3    2015      4                  23.6  ...        285.2       25.00   49
# 4    2015      5                  23.4  ...        322.4       23.00   66
# 5    2015      6                  23.1  ...         58.8       26.00   81
# 6    2015      7                  23.1  ...          0.3        5.00   85
# 7    2015      8                  23.6  ...          6.9        4.00   87
# 8    2015      9                  23.8  ...         43.2        4.00   86
# 9    2015     10                  24.5  ...         37.9        5.00   80
# 10   2015     11                  23.9  ...        455.0       24.00   53
# 11   2015     12                  23.7  ...        311.5       23.00   48
# ...

# %% [markdown]
# ## EDA & Statistik & Visualisasi

# %% [markdown]
# ### Statistik Keadaan Udara

# %%
df_keadaan_udara.shape
# Out:
# (60, 5)

# %%
df_keadaan_udara.head(5)
# Out:
#    Tahun  Bulan  Penguapan (mm)  Tekanan udara (mb)  Kelembapan Nisbi (%)
# 0   2015      1             3.8               924.0                  79.0
# 1   2015      2             3.7               923.8                  80.0
# 2   2015      3             4.0               924.1                  79.0
# 3   2015      4             3.4               923.2                  81.0
# 4   2015      5             3.1               924.1                  77.0

# %%
df_keadaan_udara.dtypes
# Out:
# Tahun                     int64
# Bulan                     int64
# Penguapan (mm)          float64
# Tekanan udara (mb)      float64
# Kelembapan Nisbi (%)    float64
# dtype: object

# %%
df_keadaan_udara.isnull().any()
# Out:
# Tahun                   False
# Bulan                   False
# Penguapan (mm)          False
# Tekanan udara (mb)      False
# Kelembapan Nisbi (%)    False
# dtype: bool

# %%
df_keadaan_udara.describe()
# Out:
#              Tahun      Bulan  ...  Tekanan udara (mb)  Kelembapan Nisbi (%)
# count    60.000000  60.000000  ...           60.000000             60.000000
# mean   2017.000000   6.500000  ...          923.445000             76.201667
# std       1.426148   3.481184  ...            0.817898              5.985420
# min    2015.000000   1.000000  ...          921.000000             63.000000
# 25%    2016.000000   3.750000  ...          923.100000             71.750000
# 50%    2017.000000   6.500000  ...          923.500000             79.000000
# 75%    2018.000000   9.250000  ...          924.000000             80.050000
# max    2019.000000  12.000000  ...          925.100000             84.000000
#
# [8 rows x 5 columns]

# %%
df_keadaan_udara.isnull().any()
# Out:
# Tahun                   False
# Bulan                   False
# Penguapan (mm)          False
# Tekanan udara (mb)      False
# Kelembapan Nisbi (%)    False
# dtype: bool

# %% [markdown]
# ### Visualisasi Keadaan Udara

# %%
import matplotlib.pyplot as plt
import pandas as pd
import pylab as pl
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
# normalisasi
viz = df_keadaan_udara[['Penguapan (mm)', 'Tekanan udara (mb)', 'Kelembapan Nisbi (%)']]
# for column in viz.columns:
#     viz[column] = (viz[column] - viz[column].min()) / (viz[column].max() - viz[column].min())

# %%
sns.heatmap(viz.corr(), annot=True)

# %%
sns.boxplot(viz['Penguapan (mm)'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(viz['Tekanan udara (mb)'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(viz['Kelembapan Nisbi (%)'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
viz.hist()
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.scatter(viz['Penguapan (mm)'], viz['Tekanan udara (mb)'],  color='blue')
plt.xlabel("Penguapan")
plt.ylabel("Tekanan udara")
plt.show()

# %%
plt.scatter(viz['Penguapan (mm)'], viz['Kelembapan Nisbi (%)'],  color='blue')
plt.xlabel("Penguapan")
plt.ylabel("Kelembapan")
plt.show()

# %%
plt.scatter(viz['Tekanan udara (mb)'], viz['Kelembapan Nisbi (%)'],  color='blue')
plt.xlabel("Tekanan Udara")
plt.ylabel("Kelembapan")
plt.show()

# %%
import matplotlib.pyplot as plt

month = np.arange(0, len(df_keadaan_udara['Bulan']), 1)

plt.plot(month, viz['Tekanan udara (mb)'])
plt.title('Keadaan Udara Berdasarkan Tekanan Udara')
plt.ylabel('Tekanan udara (mb)')
plt.xlabel('Bulan')
plt.show()

# %%
plt.plot(month, viz['Kelembapan Nisbi (%)'])
plt.title('Keadaan Udara Berdasarkan Kelembapan Udara')
plt.ylabel('Kelembapan Nisbi (%)')
plt.xlabel('Bulan')
plt.show()

# %%
plt.plot(month, viz['Penguapan (mm)'])
plt.title('Keadaan Udara Berdasarkan Penguapan')
plt.ylabel('Penguapan (mm)')
plt.xlabel('Bulan')
plt.show()

# %% [markdown]
# ### Statistik Kecepatan Udara

# %%
df_kecepatan_angin.shape
# Out:
# (60, 4)

# %%
df_kecepatan_angin.dtypes
# Out:
# Tahun                                 int64
# Bulan                                 int64
# Kecepatan Angin Rata-rata (knot)    float64
# Kecepatan Angin Terbesar (knot)     float64
# dtype: object

# %%
df_kecepatan_angin.describe()
# Out:
#              Tahun  ...  Kecepatan Angin Terbesar (knot)
# count    60.000000  ...                        60.000000
# mean   2017.000000  ...                        15.211667
# std       1.426148  ...                         5.432392
# min    2015.000000  ...                         8.000000
# 25%    2016.000000  ...                        12.000000
# 50%    2017.000000  ...                        13.000000
# 75%    2018.000000  ...                        17.000000
# max    2019.000000  ...                        29.600000
#
# [8 rows x 4 columns]

# %%
df_kecepatan_angin.isnull().any()
# Out:
# Tahun                               False
# Bulan                               False
# Kecepatan Angin Rata-rata (knot)    False
# Kecepatan Angin Terbesar (knot)     False
# dtype: bool

# %% [markdown]
# ### Visualisasi Kecepatan Udara

# %%
# normalisasi
viz = df_kecepatan_angin[['Kecepatan Angin Rata-rata (knot)', 'Kecepatan Angin Terbesar (knot)']]
# for column in viz.columns:
#     viz[column] = (viz[column] - viz[column].min()) / (viz[column].max() - viz[column].min())

# %%
sns.heatmap(viz.corr(), annot=True)

# %%
sns.boxplot(viz["Kecepatan Angin Rata-rata (knot)"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(viz["Kecepatan Angin Terbesar (knot)"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
viz.hist()
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.scatter(viz['Kecepatan Angin Rata-rata (knot)'], viz['Kecepatan Angin Terbesar (knot)'],  color='blue')
plt.xlabel("Kecepatan Angin Rata-Rata")
plt.ylabel("Kecepatang Angin Terbesar")
plt.show()

# %%
import matplotlib.pyplot as plt

month = np.arange(0, len(df_kecepatan_angin['Bulan']), 1)

plt.plot(month, viz['Kecepatan Angin Rata-rata (knot)'])
plt.title('Keadaan Angin')
plt.ylabel('Kecepatan Angin Rata-rata (knot)')
plt.xlabel('Bulan')
plt.show()

# %%
plt.plot(month, viz['Kecepatan Angin Terbesar (knot)'])
plt.title('Keadaan Angin')
plt.ylabel('Kecepatan Angin Terbesar (knot)')
plt.xlabel('Bulan')
plt.show()

# %% [markdown]
# ### Statistik Suhu dan Kelembapan Udara

# %%
df_suhu.shape
# Out:
# (60, 8)

# %%
df_suhu.dtypes
# Out:
# Tahun                     int64
# Bulan                     int64
# Temperatur Rata-rata    float64
# Temperatur Maks         float64
# Temperatur Min          float64
# Curah Hujan             float64
# Hari Hujan              float64
# LPM                       int64
# dtype: object

# %%
df_suhu.isnull().any()
# Out:
# Tahun                   False
# Bulan                   False
# Temperatur Rata-rata    False
# Temperatur Maks         False
# Temperatur Min          False
# Curah Hujan             False
# Hari Hujan              False
# LPM                     False
# dtype: bool

# %%
df_suhu.describe()
# Out:
#              Tahun      Bulan  ...  Hari Hujan        LPM
# count    60.000000  60.000000  ...   60.000000  60.000000
# mean   2017.000000   6.500000  ...   18.241667  61.566667
# std       1.426148   3.481184  ...    9.132541  14.695055
# min    2015.000000   1.000000  ...    0.460000  35.000000
# 25%    2016.000000   3.750000  ...   11.000000  51.750000
# 50%    2017.000000   6.500000  ...   23.000000  58.500000
# 75%    2018.000000   9.250000  ...   25.000000  72.750000
# max    2019.000000  12.000000  ...   30.000000  88.000000
#
# [8 rows x 8 columns]

# %% [markdown]
# ### Visualisasi Kelembapan Udara

# %%
# normalisasi
viz = df_suhu[['Temperatur Rata-rata', 'Temperatur Maks', 'Temperatur Min', 'Curah Hujan', 'Hari Hujan', 'LPM']]
# for column in viz.columns:
#     viz[column] = (viz[column] - viz[column].min()) / (viz[column].max() - viz[column].min())

# %%
sns.heatmap(viz.corr(), annot=True)

# %%
viz.hist()
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.plot(month, viz['Temperatur Rata-rata'])
plt.title('Suhu Bandung')
plt.ylabel('Temperature Rata-rata')
plt.xlabel('Bulan')
plt.show()

# %%
plt.plot(month, viz['Temperatur Maks'], marker='o')
plt.plot(month, viz['Temperatur Min'], marker='x', linestyle='--')
plt.title('Suhu Bandung')
plt.ylabel('Temperatur')
plt.xlabel('Bulan')
plt.show()

# %%
plt.plot(month, viz['LPM'])
plt.title('Suhu Bandung')
plt.ylabel('LPM')
plt.xlabel('Bulan')
plt.show()

# %% [markdown]
# ## Data Preparation

# %%
# Hasil EDA dan Visualisasi Data dipilih 5 kategori keadaan udara bandung yaitu
# Kelembapan Nisbi, Temperatur Rata-Rata, Temperatur Maks, Temperatur Min, LPM

# df = df_suhu[['Temperatur Rata-rata', 'Temperatur Maks', 'Temperatur Min', 'Curah Hujan', 'Hari Hujan', 'LPM']]
# df = df_keadaan_udara[['Penguapan (mm)', 'Tekanan udara (mb)', 'Kelembapan Nisbi (%)']]

df = pd.concat([df_keadaan_udara['Tahun'], df_keadaan_udara['Bulan'], df_keadaan_udara['Kelembapan Nisbi (%)'], df_suhu['Temperatur Rata-rata'], df_suhu['Temperatur Maks'], df_suhu['Temperatur Min'], df_suhu['LPM']], join='outer', axis=1)
df.rename(columns={
    'Kelembapan Nisbi (%)': 'kelembapan',
    'Temperatur Rata-rata': 'temp_rataan',
    'Temperatur Maks': 'temp_max',
    'Temperatur Min': 'temp_min',
}, inplace=True)

# %%
df.head()
# Out:
#    Tahun  Bulan  kelembapan  temp_rataan  temp_max  temp_min  LPM
# 0   2015      1        79.0         23.2      28.4      20.3   54
# 1   2015      2        80.0         23.1      28.9      20.2   55
# 2   2015      3        79.0         23.4      28.9      20.2   60
# 3   2015      4        81.0         23.6      29.1      20.5   49
# 4   2015      5        77.0         23.4      29.6      19.4   66

# %% [markdown]
# ## Feature Engineering (Decomposition)

# %%
import matplotlib
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd

# %matplotlib inline

# %%
def running_average(x, order):
    current = x[:order].sum()
    running = []
    
    for i in range(order, x.shape[0]):
        current += x[i]
        current -= x[i-order]
        running.append(current/order)
    
    return np.array(running)

# %% [markdown]
# ### Trend

# %%
trend = running_average(df['kelembapan'], 4)

fig, ax = plt.subplots(1, 1)
ax.plot(df.index, df['kelembapan'])
ax.set_xlabel('Bulan')
ax.set_ylabel('Kelembapan')
ax.plot(df.index[4:], trend, label='Trend')
ax.legend()

# %%
trend = running_average(df['temp_rataan'], 4)

fig, ax = plt.subplots(1, 1)
ax.plot(df.index, df['temp_rataan'])
ax.set_xlabel('Bulan')
ax.set_ylabel('temp_rataan')
ax.plot(df.index[4:], trend, label='Trend')
ax.legend()

# %%
trend = running_average(df['LPM'], 4)

fig, ax = plt.subplots(1, 1)
ax.plot(df.index, df['LPM'])
ax.set_xlabel('Bulan')
ax.set_ylabel('LPM')
ax.plot(df.index[4:], trend, label='Trend')
ax.legend()

# %%
detrended_k = df['kelembapan'].iloc[4:].values.flatten()/trend

# %%
fig, ax = plt.subplots(1, 1)
ax.plot(df.index[4:], detrended_k)
ax.set_xlabel('Bulan')
ax.set_ylabel('Detrended value Kelembapan')
# Out:
# Text(0, 0.5, 'Detrended value Kelembapan')

# %%
detrended_tr = df['temp_rataan'].iloc[4:].values.flatten()/trend
fig, ax = plt.subplots(1, 1)
ax.plot(df.index[4:], detrended_tr)
ax.set_xlabel('Bulan')
ax.set_ylabel('Detrended value temp_rataan')
# Out:
# Text(0, 0.5, 'Detrended value temp_rataan')

# %%
detrended_tr = df['LPM'].iloc[4:].values.flatten()/trend
fig, ax = plt.subplots(1, 1)
ax.plot(df.index[4:], detrended_tr)
ax.set_xlabel('Bulan')
ax.set_ylabel('Detrended value LPM')
# Out:
# Text(0, 0.5, 'Detrended value LPM')

# %% [markdown]
# ### Original, Trend, Seasonality, Residuals

# %%
# Multiplicative decomposition
def decomposition(data, order, plot=True):
    values = data.values.flatten()
    trend = running_average(values, order)
    detrended = values[order:]/trend
    
    season = [detrended[i::order].mean() for i in range(order)]
    seasonality = np.array(season*(detrended.shape[0]//order+1))[:detrended.shape[0]]
    residuals = values[order:]/(trend*seasonality)

    if plot:
        fig, axs = plt.subplots(4, 1, figsize=(22, 16), sharex=True)
        index = data.index

        axs[0].plot(index, values)
        axs[0].set_title('Original data')
        
        axs[1].plot(index[order:], trend)
        axs[1].set_title('Trend')

        axs[2].plot(index[order:], detrended)
        axs[2].set_title('Seasonality')

        axs[3].plot(index[order:], residuals)
        axs[3].set_title('Residuals')
        
    return values, trend, seasonality, residuals

# %%
values_k, trend_k, seasonality_k, residuals_k = decomposition(df['kelembapan'], 4)

# %%
values_tr, trend_tr, seasonality_tr, residuals_tr = decomposition(df['temp_rataan'], 4)

# %%
values_lpm, trend_lpm, seasonality_lpm, residuals_lpm = decomposition(df['LPM'], 4)

# %% [markdown]
# ## Pemodelan dengan DeepLearning

# %%
import datetime

import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
plt.rcParams['figure.figsize'] = (10, 7.5)
plt.rcParams['axes.grid'] = False

# %%
from tensorflow.keras import Model, Sequential

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import MeanAbsoluteError

from tensorflow.keras.layers import Dense, Conv1D, LSTM, Lambda, Reshape, RNN, LSTMCell

# %%
tf.random.set_seed(42)
np.random.seed(42)

# %%
arr = np.array([values_k, values_tr, values_lpm])
df_res = pd.DataFrame(arr.T, columns=['kelembapan', 'temp_rataan', 'lpm'])
df_res.head()
# Out:
#    kelembapan  temp_rataan   lpm
# 0        79.0         23.2  54.0
# 1        80.0         23.1  55.0
# 2        79.0         23.4  60.0
# 3        81.0         23.6  49.0
# 4        77.0         23.4  66.0

# %%
column_indices = {name: i for i, name in enumerate(df_res.columns)}

n = len(df)

train_df = df_res[0:int(n*0.7)]
val_df = df_res[int(n*0.7):int(n*0.9)]
test_df = df_res[int(n*0.9):]

num_features = df.shape[1]

print(f'There are {num_features} features')
# Out:
# There are 7 features

# %%
train_df
# Out:
#     kelembapan  temp_rataan   lpm
# 0         79.0         23.2  54.0
# 1         80.0         23.1  55.0
# 2         79.0         23.4  60.0
# 3         81.0         23.6  49.0
# 4         77.0         23.4  66.0
# 5         74.0         23.1  81.0
# 6         70.0         23.1  85.0
# 7         66.0         23.6  87.0
# 8         64.0         23.8  86.0
# 9         63.0         24.5  80.0
# 10        79.0         23.9  53.0
# 11        82.0         23.7  48.0
# 12        81.0         23.8  52.0
# 13        80.0         24.0  42.0
# 14        83.0         24.1  44.0
# 15        84.0         24.0  53.0
# 16        83.0         24.0  54.0
# 17        79.0         23.7  57.0
# 18        79.0         23.3  70.0
# 19        66.0         23.6  67.0
# 20        80.0         23.6  53.0
# 21        83.0         23.1  37.0
# 22        84.0         23.4  39.0
# 23        76.0         24.4  51.0
# 24        75.0         24.2  53.0
# 25        81.0         23.0  40.0
# ...

# %%
train_df.to_pickle('train_df.pkl')

# %%
val_df
# Out:
#     kelembapan  temp_rataan   lpm
# 42        67.2         22.9  88.0
# 43        68.6         23.3  80.0
# 44        66.1         23.7  76.0
# 45        70.7         24.2  67.0
# 46        81.3         23.7  51.0
# 47        80.2         23.7  42.0
# 48        79.0         23.7  58.0
# 49        81.0         23.8  63.0
# 50        80.0         23.6  48.0
# 51        80.0         23.9  59.0
# 52        79.0         23.9  70.0
# 53        72.0         23.3  85.0

# %%
val_df.to_pickle('val_df.pkl')

# %%
test_df
# Out:
#     kelembapan  temp_rataan   lpm
# 54        69.0         22.7  84.0
# 55        66.0         23.0  83.0
# 56        64.0         23.8  86.0
# 57        64.0         24.9  75.0
# 58        74.0         24.2  66.0
# 59        83.0         23.7  50.0

# %%
test_df.to_pickle('test_df.pkl')

# %%
class WindowGenerator():
    def __init__(self, input_width, label_width, shift, 
                 train_df=train_df, val_df=val_df, test_df=test_df, 
                 label_columns=None):
        
        self.train_df = train_df
        self.val_df = val_df
        self.test_df = test_df
        
        self.label_columns = label_columns
        if label_columns is not None:
            self.label_columns_indices = {name: i for i, name in enumerate(label_columns)}
        self.column_indices = {name: i for i, name in enumerate(train_df.columns)}
        
        self.input_width = input_width
        self.label_width = label_width
        self.shift = shift
        
        self.total_window_size = input_width + shift
        
        self.input_slice = slice(0, input_width)
        self.input_indices = np.arange(self.total_window_size)[self.input_slice]
        
        self.label_start = self.total_window_size - self.label_width
        self.labels_slice = slice(self.label_start, None)
        self.label_indices = np.arange(self.total_window_size)[self.labels_slice]
        
    def __repr__(self):
        return '\n'.join([
            f'Total window size: {self.total_window_size}',
            f'Input indices: {self.input_indices}',
            f'Label indices: {self.label_indices}',
            f'Label column name(s): {self.label_columns}'
        ])
    
    def split_window(self, features):
        inputs = features[:, self.input_slice, :]
        labels = features[:, self.labels_slice, :]
        if self.label_columns is not None:
            labels = tf.stack(
                [labels[:,:,self.column_indices[name]] for name in self.label_columns],
                axis=-1
            )
        inputs.set_shape([None, self.input_width, None])
        labels.set_shape([None, self.label_width, None])
        
        return inputs, labels
    
    def plot(self, model=None, plot_col='', max_subplots=3):
        inputs, labels = self.example
        plot_col = self.label_columns[0]
        
        plt.figure(figsize=(12, 8))
        plot_col_index = self.column_indices[plot_col]
        max_n = min(max_subplots, len(inputs))
        
        for n in range(max_n):
            plt.subplot(3, 1, n+1)
            plt.ylabel(f'{plot_col} [normed]')
            plt.plot(self.input_indices, inputs[n, :, plot_col_index],
                     label='Inputs', marker='.', zorder=-10)

            if self.label_columns:
              label_col_index = self.label_columns_indices.get(plot_col, None)
            else:
              label_col_index = plot_col_index

            if label_col_index is None:
              continue

            plt.scatter(self.label_indices, labels[n, :, label_col_index],
                        edgecolors='k', label='Labels', c='#2ca02c', s=64)
            if model is not None:
              predictions = model(inputs)
              plt.scatter(self.label_indices, predictions[n, :, label_col_index],
                          marker='X', edgecolors='k', label='Predictions',
                          c='#ff7f0e', s=64)

            if n == 0:
              plt.legend()

        plt.xlabel('Month')
        
    def make_dataset(self, data):
        data = np.array(data, dtype=np.float32)
        ds = tf.keras.preprocessing.timeseries_dataset_from_array(
            data=data,
            targets=None,
            sequence_length=self.total_window_size,
            sequence_stride=1,
            shuffle=True,
            batch_size=32
        )
        
        ds = ds.map(self.split_window)
        return ds
    
    @property
    def train(self):
        return self.make_dataset(self.train_df)
    
    @property
    def val(self):
        return self.make_dataset(self.val_df)
    
    @property
    def test(self):
        return self.make_dataset(self.test_df)
    
    @property
    def example(self):
        result = getattr(self, '_example', None)
        if result is None:
            result = next(iter(self.train))
            self._example = result
        return result

# %%
MAX_EPOCHS = 50

def compile_and_fit(model, window, patience=3):
    early_stopping = EarlyStopping(monitor='val_loss', 
                                   patience=patience, 
                                   mode='min')
    
    model.compile(loss=MeanSquaredError(), 
                  optimizer=Adam(), 
                  metrics=[MeanAbsoluteError()])
    
    history = model.fit(window.train,
                       epochs=MAX_EPOCHS,
                       validation_data=window.val,
                       callbacks=[early_stopping])
    
    return history

# %%
single_step_window = WindowGenerator(input_width=1, label_width=1, shift=0, label_columns=['kelembapan'])

single_step_window
# Out:
# Total window size: 1
# Input indices: [0]
# Label indices: [0]
# Label column name(s): ['kelembapan']

# %%
class Baseline(Model):
    def __init__(self, label_index=None):
        super().__init__()
        self.label_index = label_index
        
    def call(self, inputs):
        if self.label_index is None:
            return inputs
        result = inputs[:, :, self.label_index]
        return result[:,:,tf.newaxis]

# %%
baseline = Baseline(label_index=column_indices['kelembapan'])

baseline.compile(loss=MeanSquaredError(),
                metrics=[MeanAbsoluteError()])

# %%
baseline.summary()
# Out:
# Model: "baseline_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# Total params: 0
# Trainable params: 0
# Non-trainable params: 0
# _________________________________________________________________

# %%
val_performance = {}
performance = {}

val_performance['Baseline'] = baseline.evaluate(single_step_window.val)
performance['Baseline'] = baseline.evaluate(single_step_window.test, verbose=0)
# Out:
# 1/1 [==============================] - 0s 115ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0000e+00

# %%
single_step_window.test
# Out:
# <MapDataset shapes: ((None, 1, 3), (None, 1, 1)), types: (tf.float32, tf.float32)>

# %%
single_step_window.test
# Out:
# <MapDataset shapes: ((None, 1, 3), (None, 1, 1)), types: (tf.float32, tf.float32)>

# %%
baseline.predict(single_step_window.test, verbose=0)
# Out:
# array([[[64.]],
#
#        [[69.]],
#
#        [[83.]],
#
#        [[64.]],
#
#        [[66.]],
#
#        [[74.]]], dtype=float32)

# %%
performance
# Out:
# {'Baseline': [0.5359994769096375, 0.6799995303153992]}

# %%
wide_window = WindowGenerator(input_width=6,
                             label_width=6,
                             shift=1,
                             label_columns=['kelembapan'])

wide_window
# Out:
# Total window size: 7
# Input indices: [0 1 2 3 4 5]
# Label indices: [1 2 3 4 5 6]
# Label column name(s): ['kelembapan']

# %%
wide_window.plot(baseline)

# %%
single_step_window.test
# Out:
# <MapDataset shapes: ((None, 1, 3), (None, 1, 1)), types: (tf.float32, tf.float32)>

# %%
linear = Sequential([
    Dense(units=1)
])

# %%
history = compile_and_fit(linear, single_step_window)

val_performance['linear'] = linear.evaluate(single_step_window.val)
performance['linear'] = linear.evaluate(single_step_window.test, verbose=0)
# Out:
# Epoch 1/50
# 2/2 [==============================] - 1s 148ms/step - loss: 7401.4121 - mean_absolute_error: 85.9668 - val_loss: 7593.5454 - val_mean_absolute_error: 87.0817
# Epoch 2/50
# 2/2 [==============================] - 0s 49ms/step - loss: 7346.2314 - mean_absolute_error: 85.6459 - val_loss: 7535.8965 - val_mean_absolute_error: 86.7507
# Epoch 3/50
# 2/2 [==============================] - 0s 51ms/step - loss: 7291.1606 - mean_absolute_error: 85.3246 - val_loss: 7478.4688 - val_mean_absolute_error: 86.4198
# Epoch 4/50
# 2/2 [==============================] - 0s 55ms/step - loss: 7236.8037 - mean_absolute_error: 85.0055 - val_loss: 7421.3477 - val_mean_absolute_error: 86.0893
# Epoch 5/50
# 2/2 [==============================] - 0s 49ms/step - loss: 7181.5596 - mean_absolute_error: 84.6821 - val_loss: 7364.5024 - val_mean_absolute_error: 85.7591
# Epoch 6/50
# ...

# %%
performance['linear']
# Out:
# [3020.354736328125, 53.97941207885742]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras

# %%
linear.save('linear_kelembapan.h5')

# %%
wide_window.plot(linear)

# %%
wide_window
# Out:
# Total window size: 7
# Input indices: [0 1 2 3 4 5]
# Label indices: [1 2 3 4 5 6]
# Label column name(s): ['kelembapan']

# %%
dense = Sequential([
    Dense(units=64, activation='relu'),
    Dense(units=64, activation='relu'),
    Dense(units=1)
])

history = compile_and_fit(dense, single_step_window)

val_performance['dense'] = dense.evaluate(single_step_window.val)
performance['dense'] = dense.evaluate(single_step_window.test, verbose=0)
# Out:
# Epoch 1/50
# 2/2 [==============================] - 1s 199ms/step - loss: 10847.3398 - mean_absolute_error: 104.0222 - val_loss: 9352.1680 - val_mean_absolute_error: 96.5542
# Epoch 2/50
# 2/2 [==============================] - 0s 52ms/step - loss: 9464.7646 - mean_absolute_error: 97.1498 - val_loss: 8080.2124 - val_mean_absolute_error: 89.7494
# Epoch 3/50
# 2/2 [==============================] - 0s 52ms/step - loss: 8169.0708 - mean_absolute_error: 90.2566 - val_loss: 6938.4941 - val_mean_absolute_error: 83.1635
# Epoch 4/50
# 2/2 [==============================] - 0s 52ms/step - loss: 7015.6382 - mean_absolute_error: 83.6526 - val_loss: 5976.4438 - val_mean_absolute_error: 77.1711
# Epoch 5/50
# 2/2 [==============================] - 0s 54ms/step - loss: 6068.0132 - mean_absolute_error: 77.7899 - val_loss: 5181.4341 - val_mean_absolute_error: 71.8322
# Epoch 6/50
# ...

# %%
wide_window.plot(dense)

# %%
result = dense.predict(single_step_window.test, verbose=0)

# %%
for r in result:
  print(r[0][0])
# Out:
# 74.83326
# 80.57669
# 77.514244
# 80.75052
# 83.642075
# 78.03648

# %%
dense.save('dense_kelembapan.h5')

# %%
lstm_model = Sequential([
    LSTM(32, return_sequences=True),
    Dense(units=1)
])

history = compile_and_fit(lstm_model, single_step_window)

val_performance['LSTM'] = lstm_model.evaluate(single_step_window.val)
performance['LSTM'] = lstm_model.evaluate(single_step_window.test, verbose=0)
# Out:
# Epoch 1/50
# 2/2 [==============================] - 3s 456ms/step - loss: 3659.8416 - mean_absolute_error: 58.9348 - val_loss: 4528.5254 - val_mean_absolute_error: 65.8114
# Epoch 2/50
# 2/2 [==============================] - 0s 53ms/step - loss: 3656.2805 - mean_absolute_error: 58.9063 - val_loss: 4522.7778 - val_mean_absolute_error: 65.7711
# Epoch 3/50
# 2/2 [==============================] - 0s 52ms/step - loss: 3652.4714 - mean_absolute_error: 58.8749 - val_loss: 4516.9731 - val_mean_absolute_error: 65.7296
# Epoch 4/50
# 2/2 [==============================] - 0s 56ms/step - loss: 3648.0847 - mean_absolute_error: 58.8396 - val_loss: 4510.9941 - val_mean_absolute_error: 65.6864
# Epoch 5/50
# 2/2 [==============================] - 0s 54ms/step - loss: 3643.1582 - mean_absolute_error: 58.7998 - val_loss: 4504.7441 - val_mean_absolute_error: 65.6405
# Epoch 6/50
# ...

# %%
wide_window.plot(lstm_model)
